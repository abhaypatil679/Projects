# %%
from json import loads
from copy import deepcopy
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 80)
pd.set_option('display.max_rows', 80)

# %%
df = pd.read_csv('./dataset/test.csv',index_col='Id')
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
# ...          ...       ...       ...       ...          ...        ...
# 2915         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2916         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2917         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2918         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2919         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6       1961
# 1462       Norm     1Fam     1Story            6            6       1958
# 1463       Norm     1Fam     2Story            5            5       1997
# 1464       Norm     1Fam     2Story            6            6       1998
# 1465       Norm   TwnhsE     1Story            8            5       1992
# ...         ...      ...        ...          ...          ...        ...
# 2915       Norm    Twnhs     2Story            4            7       1970
# 2916       Norm   TwnhsE     2Story            4            5       1970
# 2917       Norm     1Fam     1Story            5            7       1960
# 2918       Norm     1Fam     SFoyer            5            5       1992
# 2919       Norm     1Fam     2Story            7            5       1993
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1462          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463          1998     Gable  CompShg     VinylSd     VinylSd       None
# 1464          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465          1992     Gable  CompShg     HdBoard     HdBoard       None
# ...            ...       ...      ...         ...         ...        ...
# 2915          1970     Gable  CompShg     CemntBd     CmentBd       None
# 2916          1970     Gable  CompShg     CemntBd     CmentBd       None
# 2917          1996     Gable  CompShg     VinylSd     VinylSd       None
# 2918          1992     Gable  CompShg     HdBoard     Wd Shng       None
# 2919          1994     Gable  CompShg     HdBoard     HdBoard    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 2915         0.0        TA        TA     CBlock       TA       TA
# 2916         0.0        TA        TA     CBlock       TA       TA
# 2917         0.0        TA        TA     CBlock       TA       TA
# 2918         0.0        TA        TA      PConc       Gd       TA
# 2919        94.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
# ...           ...          ...         ...          ...         ...
# 2915           No          Unf         0.0          Unf         0.0
# 2916           No          Rec       252.0          Unf         0.0
# 2917           No          ALQ      1224.0          Unf         0.0
# 2918           Av          GLQ       337.0          Unf         0.0
# 2919           Av          LwQ       758.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 2915      546.0        546.0    GasA        Gd          Y      SBrkr
# 2916      294.0        546.0    GasA        TA          Y      SBrkr
# 2917        0.0       1224.0    GasA        Ex          Y      SBrkr
# 2918      575.0        912.0    GasA        TA          Y      SBrkr
# 2919      238.0        996.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
# ...        ...       ...           ...        ...           ...           ...
# 2915       546       546             0       1092           0.0           0.0
# 2916       546       546             0       1092           0.0           0.0
# 2917      1224         0             0       1224           1.0           0.0
# 2918       970         0             0        970           0.0           1.0
# 2919       996      1004             0       2000           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
# ...        ...       ...           ...           ...         ...
# 2915         1         1             3             1          TA
# 2916         1         1             3             1          TA
# 2917         1         0             4             1          TA
# 2918         1         0             3             1          TA
# 2919         2         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0         NaN     Attchd       1961.0
# 1462             6        Typ           0         NaN     Attchd       1958.0
# 1463             6        Typ           1          TA     Attchd       1997.0
# 1464             7        Typ           1          Gd     Attchd       1998.0
# 1465             5        Typ           0         NaN     Attchd       1992.0
# ...            ...        ...         ...         ...        ...          ...
# 2915             5        Typ           0         NaN        NaN          NaN
# 2916             6        Typ           0         NaN    CarPort       1970.0
# 2917             7        Typ           1          TA     Detchd       1960.0
# 2918             6        Typ           0         NaN        NaN          NaN
# 2919             9        Typ           1          TA     Attchd       1993.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 2915          NaN         0.0         0.0        NaN        NaN          Y
# 2916          Unf         1.0       286.0         TA         TA          Y
# 2917          Unf         2.0       576.0         TA         TA          Y
# 2918          NaN         0.0         0.0        NaN        NaN          Y
# 2919          Fin         3.0       650.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
# ...          ...          ...            ...        ...          ...
# 2915           0            0              0          0            0
# 2916           0           24              0          0            0
# 2917         474            0              0          0            0
# 2918          80           32              0          0            0
# 2919         190           48              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1461         0    NaN  MnPrv         NaN        0       6    2010       WD
# 1462         0    NaN    NaN        Gar2    12500       6    2010       WD
# 1463         0    NaN  MnPrv         NaN        0       3    2010       WD
# 1464         0    NaN    NaN         NaN        0       6    2010       WD
# 1465         0    NaN    NaN         NaN        0       1    2010       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 2915         0    NaN    NaN         NaN        0       6    2006       WD
# 2916         0    NaN    NaN         NaN        0       4    2006       WD
# 2917         0    NaN    NaN         NaN        0       9    2006       WD
# 2918         0    NaN  MnPrv        Shed      700       7    2006       WD
# 2919         0    NaN    NaN         NaN        0      11    2006       WD
#
#      SaleCondition
# Id
# 1461        Normal
# 1462        Normal
# 1463        Normal
# 1464        Normal
# 1465        Normal
# ...            ...
# 2915        Normal
# 2916       Abnorml
# 2917       Abnorml
# 2918        Normal
# 2919        Normal
#
# [1459 rows x 79 columns]

# %%
col_continuous = ['GrLivArea', 'LotArea', 'BsmtFinSF1', 'BsmtUnfSF', '1stFlrSF', 'TotalBsmtSF', 'GarageArea','2ndFlrSF', 'BsmtFinSF2', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'LotFrontage', 'ScreenPorch']
col_catagorial = ['Neighborhood', 'Exterior2nd', 'MSSubClass', 'Exterior1st', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'MoSold', 'TotRmsAbvGrd', 'OverallQual', 'OverallCond', 'Condition1', 'SaleType', 'RoofMatl', 'BedroomAbvGr', 'Condition2', 'HouseStyle', 'Functional', 'GarageType', 'SaleCondition', 'RoofStyle', 'Electrical', 'Heating', 'BsmtFinType2', 'BsmtFinType1', 'Foundation', 'BldgType', 'MSZoning', 'GarageCond', 'YrSold', 'GarageQual', 'ExterCond', 'GarageCars', 'LotConfig', 'HeatingQC', 'Fireplaces', 'LandContour', 'KitchenQual', 'MasVnrType', 'FullBath', 'BsmtFullBath', 'KitchenAbvGr', 'LotShape', 'BsmtExposure', 'BsmtCond', 'BsmtQual', 'ExterQual', 'HalfBath','GarageFinish', 'BsmtHalfBath', 'LandSlope', 'PavedDrive', 'Utilities','Street', 'CentralAir','FireplaceQu']

# %%
with open('./data_dict_equations.json','rt') as f:
    data_dict_continuous = loads(f.read())
data_dict_continuous
# Out:
# {'2ndFlrSF': '+0.06*(x**2)+98.59*(x**1)+71631.97*(x**0)',
#  'GrLivArea': '+103.69*(x**1)+22362.6*(x**0)',
#  'LotArea': '+8.65*(x**1)+96145.5*(x**0)',
#  'BsmtFinSF1': '+0.09*(x**2)+-26.62*(x**1)+146988.42*(x**0)',
#  'BsmtUnfSF': '+18.26*(x**1)+166525.59*(x**0)',
#  '1stFlrSF': '+121.53*(x**1)+37790.65*(x**0)',
#  'TotalBsmtSF': '+122.09*(x**1)+48499.91*(x**0)',
#  'GarageArea': '+251.97*(x**1)+56662.96*(x**0)',
#  'WoodDeckSF': '+136.18*(x**1)+174518.22*(x**0)',
#  'OpenPorchSF': '+130.05*(x**1)+194337.81*(x**0)',
#  'BsmtFinSF2': '+29.7*(x**1)+149161.31*(x**0)',
#  'EnclosedPorch': '+172.75*(x**1)+118584.92*(x**0)',
#  'LotFrontage': '+1312.97*(x**1)+86274.97*(x**0)',
#  'ScreenPorch': '+214.49*(x**1)+152419.64*(x**0)'}

# %%
df_continuous = deepcopy(df[col_continuous])
df_continuous
# Out:
#       GrLivArea  LotArea  BsmtFinSF1  BsmtUnfSF  1stFlrSF  TotalBsmtSF  \
# Id
# 1461        896    11622       468.0      270.0       896        882.0
# 1462       1329    14267       923.0      406.0      1329       1329.0
# 1463       1629    13830       791.0      137.0       928        928.0
# 1464       1604     9978       602.0      324.0       926        926.0
# 1465       1280     5005       263.0     1017.0      1280       1280.0
# ...         ...      ...         ...        ...       ...          ...
# 2915       1092     1936         0.0      546.0       546        546.0
# 2916       1092     1894       252.0      294.0       546        546.0
# 2917       1224    20000      1224.0        0.0      1224       1224.0
# 2918        970    10441       337.0      575.0       970        912.0
# 2919       2000     9627       758.0      238.0       996        996.0
#
#       GarageArea  2ndFlrSF  BsmtFinSF2  WoodDeckSF  OpenPorchSF  \
# Id
# 1461       730.0         0       144.0         140            0
# 1462       312.0         0         0.0         393           36
# 1463       482.0       701         0.0         212           34
# 1464       470.0       678         0.0         360           36
# 1465       506.0         0         0.0           0           82
# ...          ...       ...         ...         ...          ...
# 2915         0.0       546         0.0           0            0
# 2916       286.0       546         0.0           0           24
# 2917       576.0         0         0.0         474            0
# 2918         0.0         0         0.0          80           32
# 2919       650.0      1004         0.0         190           48
#
#       EnclosedPorch  LotFrontage  ScreenPorch
# Id
# 1461              0         80.0          120
# 1462              0         81.0            0
# 1463              0         74.0            0
# 1464              0         78.0            0
# 1465              0         43.0          144
# ...             ...          ...          ...
# 2915              0         21.0            0
# 2916              0         21.0            0
# 2917              0        160.0            0
# 2918              0         62.0            0
# 2919              0         74.0            0
#
# [1459 rows x 14 columns]

# %%
df_continuous.isna().sum()
# Out:
# GrLivArea          0
# LotArea            0
# BsmtFinSF1         1
# BsmtUnfSF          1
# 1stFlrSF           0
# TotalBsmtSF        1
# GarageArea         1
# 2ndFlrSF           0
# BsmtFinSF2         1
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# LotFrontage      227
# ScreenPorch        0
# dtype: int64

# %%
df_continuous['BsmtFinSF1'].fillna(df_continuous['BsmtFinSF1'].mean(),inplace=True)
df_continuous['BsmtUnfSF'].fillna(df_continuous['BsmtUnfSF'].mean(),inplace=True)
df_continuous['TotalBsmtSF'].fillna(df_continuous['TotalBsmtSF'].mean(),inplace=True)
df_continuous['GarageArea'].fillna(df_continuous['GarageArea'].mean(),inplace=True)
df_continuous['BsmtFinSF2'].fillna(df_continuous['BsmtFinSF2'].mean(),inplace=True)
df_continuous['LotFrontage'].fillna(df_continuous['LotFrontage'].mean(),inplace=True)

df_continuous.isna().sum()
# Out:
# GrLivArea        0
# LotArea          0
# BsmtFinSF1       0
# BsmtUnfSF        0
# 1stFlrSF         0
# TotalBsmtSF      0
# GarageArea       0
# 2ndFlrSF         0
# BsmtFinSF2       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# LotFrontage      0
# ScreenPorch      0
# dtype: int64

# %%
def get_saleprice_continuous(col_as_series):
        x = col_as_series.values
        return eval(data_dict_continuous[col_as_series.name])

# %%
df_train_continuous =df_continuous.apply(axis='index',func=get_saleprice_continuous)
df_train_continuous
# Out:
#       GrLivArea    LotArea  BsmtFinSF1  BsmtUnfSF   1stFlrSF  TotalBsmtSF  \
# Id
# 1461  115268.84  196675.80   154242.42  171455.79  146681.53    156183.29
# 1462  160166.61  219555.05   199091.77  173939.15  199304.02    210757.52
# 1463  191273.61  215775.00   182243.29  169027.21  150570.49    161799.43
# 1464  188681.36  182455.20   163579.54  172441.83  150327.43    161555.25
# 1465  155085.80  139438.75   146212.57  185096.01  193349.05    204775.11
# ...         ...        ...         ...        ...        ...          ...
# 2915  135592.08  112891.90   146988.42  176495.55  104146.03    115161.05
# 2916  135592.08  112528.60   145995.54  171894.03  104146.03    115161.05
# 2917  149279.16  269145.50   249241.38  166525.59  186543.37    197938.07
# 2918  122941.90  186460.15   148238.69  177025.09  155674.75    159845.99
# 2919  229742.60  179419.05   178521.22  170871.47  158834.53    170101.55
#
#       GarageArea   2ndFlrSF  BsmtFinSF2  WoodDeckSF  OpenPorchSF  \
# Id
# 1461   240601.06   71631.97   153438.11   193583.42    194337.81
# 1462   135277.60   71631.97   149161.31   228036.96    199019.61
# 1463   178112.50  170227.62   149161.31   203388.38    198759.51
# 1464   175088.86  166057.03   149161.31   223543.02    199019.61
# 1465   184159.78   71631.97   149161.31   174518.22    205001.91
# ...          ...        ...         ...         ...          ...
# 2915    56662.96  143349.07   149161.31   174518.22    194337.81
# 2916   128726.38  143349.07   149161.31   174518.22    197459.01
# 2917   201797.68   71631.97   149161.31   239067.54    194337.81
# 2918    56662.96   71631.97   149161.31   185412.62    198499.41
# 2919   220443.46  231097.29   149161.31   200392.42    200580.21
#
#       EnclosedPorch  LotFrontage  ScreenPorch
# Id
# 1461      118584.92    191312.57    178158.44
# 1462      118584.92    192625.54    152419.64
# 1463      118584.92    183434.75    152419.64
# 1464      118584.92    188686.63    152419.64
# 1465      118584.92    142732.68    183306.20
# ...             ...          ...          ...
# 2915      118584.92    113847.34    152419.64
# 2916      118584.92    113847.34    152419.64
# 2917      118584.92    296350.17    152419.64
# 2918      118584.92    167679.11    152419.64
# 2919      118584.92    183434.75    152419.64
#
# [1459 rows x 14 columns]

# %%
df_categorical = deepcopy(df[col_catagorial])
df_categorical
# Out:
#      Neighborhood Exterior2nd  MSSubClass Exterior1st  YearBuilt  \
# Id
# 1461        NAmes     VinylSd          20     VinylSd       1961
# 1462        NAmes     Wd Sdng          20     Wd Sdng       1958
# 1463      Gilbert     VinylSd          60     VinylSd       1997
# 1464      Gilbert     VinylSd          60     VinylSd       1998
# 1465      StoneBr     HdBoard         120     HdBoard       1992
# ...           ...         ...         ...         ...        ...
# 2915      MeadowV     CmentBd         160     CemntBd       1970
# 2916      MeadowV     CmentBd         160     CemntBd       1970
# 2917      Mitchel     VinylSd          20     VinylSd       1960
# 2918      Mitchel     Wd Shng          85     HdBoard       1992
# 2919      Mitchel     HdBoard          60     HdBoard       1993
#
#       YearRemodAdd  GarageYrBlt  MoSold  TotRmsAbvGrd  OverallQual  \
# Id
# 1461          1961       1961.0       6             5            5
# 1462          1958       1958.0       6             6            6
# 1463          1998       1997.0       3             6            5
# 1464          1998       1998.0       6             7            6
# 1465          1992       1992.0       1             5            8
# ...            ...          ...     ...           ...          ...
# 2915          1970          NaN       6             5            4
# 2916          1970       1970.0       4             6            4
# 2917          1996       1960.0       9             7            5
# 2918          1992          NaN       7             6            5
# 2919          1994       1993.0      11             9            7
#
#       OverallCond Condition1 SaleType RoofMatl  BedroomAbvGr Condition2  \
# Id
# 1461            6      Feedr       WD  CompShg             2       Norm
# 1462            6       Norm       WD  CompShg             3       Norm
# 1463            5       Norm       WD  CompShg             3       Norm
# 1464            6       Norm       WD  CompShg             3       Norm
# 1465            5       Norm       WD  CompShg             2       Norm
# ...           ...        ...      ...      ...           ...        ...
# 2915            7       Norm       WD  CompShg             3       Norm
# 2916            5       Norm       WD  CompShg             3       Norm
# 2917            7       Norm       WD  CompShg             4       Norm
# 2918            5       Norm       WD  CompShg             3       Norm
# 2919            5       Norm       WD  CompShg             3       Norm
#
#      HouseStyle Functional GarageType SaleCondition RoofStyle Electrical  \
# Id
# 1461     1Story        Typ     Attchd        Normal     Gable      SBrkr
# 1462     1Story        Typ     Attchd        Normal       Hip      SBrkr
# 1463     2Story        Typ     Attchd        Normal     Gable      SBrkr
# 1464     2Story        Typ     Attchd        Normal     Gable      SBrkr
# 1465     1Story        Typ     Attchd        Normal     Gable      SBrkr
# ...         ...        ...        ...           ...       ...        ...
# 2915     2Story        Typ        NaN        Normal     Gable      SBrkr
# 2916     2Story        Typ    CarPort       Abnorml     Gable      SBrkr
# 2917     1Story        Typ     Detchd       Abnorml     Gable      SBrkr
# 2918     SFoyer        Typ        NaN        Normal     Gable      SBrkr
# 2919     2Story        Typ     Attchd        Normal     Gable      SBrkr
#
#      Heating BsmtFinType2 BsmtFinType1 Foundation BldgType MSZoning  \
# Id
# 1461    GasA          LwQ          Rec     CBlock     1Fam       RH
# 1462    GasA          Unf          ALQ     CBlock     1Fam       RL
# 1463    GasA          Unf          GLQ      PConc     1Fam       RL
# 1464    GasA          Unf          GLQ      PConc     1Fam       RL
# 1465    GasA          Unf          ALQ      PConc   TwnhsE       RL
# ...      ...          ...          ...        ...      ...      ...
# 2915    GasA          Unf          Unf     CBlock    Twnhs       RM
# 2916    GasA          Unf          Rec     CBlock   TwnhsE       RM
# 2917    GasA          Unf          ALQ     CBlock     1Fam       RL
# 2918    GasA          Unf          GLQ      PConc     1Fam       RL
# 2919    GasA          Unf          LwQ      PConc     1Fam       RL
#
#      GarageCond  YrSold GarageQual ExterCond  GarageCars LotConfig HeatingQC  \
# Id
# 1461         TA    2010         TA        TA         1.0    Inside        TA
# 1462         TA    2010         TA        TA         1.0    Corner        TA
# 1463         TA    2010         TA        TA         2.0    Inside        Gd
# 1464         TA    2010         TA        TA         2.0    Inside        Ex
# 1465         TA    2010         TA        TA         2.0    Inside        Ex
# ...         ...     ...        ...       ...         ...       ...       ...
# 2915        NaN    2006        NaN        TA         0.0    Inside        Gd
# 2916         TA    2006         TA        TA         1.0    Inside        TA
# 2917         TA    2006         TA        TA         2.0    Inside        Ex
# 2918        NaN    2006        NaN        TA         0.0    Inside        TA
# 2919         TA    2006         TA        TA         3.0    Inside        Ex
#
#       Fireplaces LandContour KitchenQual MasVnrType  FullBath  BsmtFullBath  \
# Id
# 1461           0         Lvl          TA       None         1           0.0
# 1462           0         Lvl          Gd    BrkFace         1           0.0
# 1463           1         Lvl          TA       None         2           0.0
# 1464           1         Lvl          Gd    BrkFace         2           0.0
# 1465           0         HLS          Gd       None         2           0.0
# ...          ...         ...         ...        ...       ...           ...
# 2915           0         Lvl          TA       None         1           0.0
# 2916           0         Lvl          TA       None         1           0.0
# 2917           1         Lvl          TA       None         1           1.0
# 2918           0         Lvl          TA       None         1           0.0
# 2919           1         Lvl          TA    BrkFace         2           0.0
#
#       KitchenAbvGr LotShape BsmtExposure BsmtCond BsmtQual ExterQual  \
# Id
# 1461             1      Reg           No       TA       TA        TA
# 1462             1      IR1           No       TA       TA        TA
# 1463             1      IR1           No       TA       Gd        TA
# 1464             1      IR1           No       TA       TA        TA
# 1465             1      IR1           No       TA       Gd        Gd
# ...            ...      ...          ...      ...      ...       ...
# 2915             1      Reg           No       TA       TA        TA
# 2916             1      Reg           No       TA       TA        TA
# 2917             1      Reg           No       TA       TA        TA
# 2918             1      Reg           Av       TA       Gd        TA
# 2919             1      Reg           Av       TA       Gd        TA
#
#       HalfBath GarageFinish  BsmtHalfBath LandSlope PavedDrive Utilities  \
# Id
# 1461         0          Unf           0.0       Gtl          Y    AllPub
# 1462         1          Unf           0.0       Gtl          Y    AllPub
# 1463         1          Fin           0.0       Gtl          Y    AllPub
# 1464         1          Fin           0.0       Gtl          Y    AllPub
# 1465         0          RFn           0.0       Gtl          Y    AllPub
# ...        ...          ...           ...       ...        ...       ...
# 2915         1          NaN           0.0       Gtl          Y    AllPub
# 2916         1          Unf           0.0       Gtl          Y    AllPub
# 2917         0          Unf           0.0       Gtl          Y    AllPub
# 2918         0          NaN           1.0       Gtl          Y    AllPub
# 2919         1          Fin           0.0       Mod          Y    AllPub
#
#      Street CentralAir FireplaceQu
# Id
# 1461   Pave          Y         NaN
# 1462   Pave          Y         NaN
# 1463   Pave          Y          TA
# 1464   Pave          Y          Gd
# 1465   Pave          Y         NaN
# ...     ...        ...         ...
# 2915   Pave          Y         NaN
# 2916   Pave          Y         NaN
# 2917   Pave          Y          TA
# 2918   Pave          Y         NaN
# 2919   Pave          Y          TA
#
# [1459 rows x 56 columns]

# %%
with open('./data_dict_median.json','rt') as f:
    data_dict_median = loads(f.read())

# %%
def get_saleprice_categorical(col_as_series):
    
    result = []
    col_as_series_str = col_as_series.astype('str')
    
    for cat_val in col_as_series_str.values:
        if cat_val in data_dict_median[col_as_series_str.name]:
            result.append(data_dict_median[col_as_series_str.name][cat_val])
        else:
            # print(f"appending {data_dict_median[col_as_series_str.name]['Other']}",col_as_series_str.name , 'for val', cat_val)
            result.append(data_dict_median[col_as_series_str.name]['Other'])
    return np.array(result)

# %%
df_train_categorical =df_categorical.apply(axis='index',func=get_saleprice_categorical)
df_train_categorical
# Out:
#       Neighborhood  Exterior2nd  MSSubClass  Exterior1st  YearBuilt  \
# Id
# 1461      140000.0     200070.5    159250.0     200000.0   138225.0
# 1462      140000.0     138000.0    159250.0     138943.5   139500.0
# 1463      181000.0     200070.5    215200.0     200000.0   207600.0
# 1464      181000.0     200070.5    215200.0     200000.0   211000.0
# 1465      278000.0     155000.0    192000.0     149900.0   189000.0
# ...            ...          ...         ...          ...        ...
# 2915       88000.0     238750.0    146000.0     236500.0   124750.0
# 2916       88000.0     238750.0    146000.0     236500.0   124750.0
# 2917      153500.0     200070.5    159250.0     200000.0   154300.0
# 2918      153500.0     138225.0    140750.0     149900.0   189000.0
# 2919      153500.0     155000.0    215200.0     149900.0   194500.0
#
#       YearRemodAdd    GarageYrBlt    MoSold  TotRmsAbvGrd  OverallQual  \
# Id
# 1461      132750.0  135000.000000  163000.0      130250.0     133000.0
# 1462      136000.0  139000.000000  163000.0      155000.0     160000.0
# 1463      195700.0  200000.000000  165250.0      155000.0     133000.0
# 1464      195700.0  199900.000000  163000.0      184100.0     160000.0
# 1465      170000.0  189000.000000  151650.0      130250.0     269750.0
# ...            ...            ...       ...           ...          ...
# 2915      129250.0  160158.757732  163000.0      130250.0     108000.0
# 2916      129250.0  146500.000000  147000.0      155000.0     108000.0
# 2917      168250.0  151500.000000  185900.0      184100.0     133000.0
# 2918      170000.0  160158.757732  165195.0      155000.0     133000.0
# 2919      207750.0  193750.000000  173000.0      252000.0     200141.0
#
#       OverallCond  Condition1  SaleType  RoofMatl  BedroomAbvGr  Condition2  \
# Id
# 1461     142750.0    140000.0  158000.0  162000.0      137250.0    163500.0
# 1462     142750.0    166500.0  158000.0  162000.0      169945.0    163500.0
# 1463     185000.0    166500.0  158000.0  162000.0      169945.0    163500.0
# 1464     142750.0    166500.0  158000.0  162000.0      169945.0    163500.0
# 1465     185000.0    166500.0  158000.0  162000.0      137250.0    163500.0
# ...           ...         ...       ...       ...           ...         ...
# 2915     145000.0    166500.0  158000.0  162000.0      169945.0    163500.0
# 2916     185000.0    166500.0  158000.0  162000.0      169945.0    163500.0
# 2917     145000.0    166500.0  158000.0  162000.0      193500.0    163500.0
# 2918     185000.0    166500.0  158000.0  162000.0      169945.0    163500.0
# 2919     185000.0    166500.0  158000.0  162000.0      169945.0    163500.0
#
#       HouseStyle  Functional  GarageType  SaleCondition  RoofStyle  \
# Id
# 1461    154750.0    165500.0    185000.0       160000.0   160000.0
# 1462    154750.0    165500.0    185000.0       160000.0   176500.0
# 1463    190000.0    165500.0    185000.0       160000.0   160000.0
# 1464    190000.0    165500.0    185000.0       160000.0   160000.0
# 1465    154750.0    165500.0    185000.0       160000.0   160000.0
# ...          ...         ...         ...            ...        ...
# 2915    190000.0    165500.0    159500.0       160000.0   160000.0
# 2916    190000.0    165500.0    108000.0       130000.0   160000.0
# 2917    154750.0    165500.0    129500.0       130000.0   160000.0
# 2918    135960.0    165500.0    159500.0       160000.0   160000.0
# 2919    190000.0    165500.0    185000.0       160000.0   160000.0
#
#       Electrical   Heating  BsmtFinType2  BsmtFinType1  Foundation  BldgType  \
# Id
# 1461    170000.0  164500.0      154000.0      142000.0    141500.0  167900.0
# 1462    170000.0  164500.0      167000.0      149250.0    141500.0  167900.0
# 1463    170000.0  164500.0      167000.0      213750.0    205000.0  167900.0
# 1464    170000.0  164500.0      167000.0      213750.0    205000.0  167900.0
# 1465    170000.0  164500.0      167000.0      149250.0    205000.0  172200.0
# ...          ...       ...           ...           ...         ...       ...
# 2915    170000.0  164500.0      167000.0      161750.0    141500.0  137500.0
# 2916    170000.0  164500.0      167000.0      142000.0    141500.0  172200.0
# 2917    170000.0  164500.0      167000.0      149250.0    141500.0  167900.0
# 2918    170000.0  164500.0      167000.0      213750.0    205000.0  167900.0
# 2919    170000.0  164500.0      167000.0      139000.0    205000.0  167900.0
#
#       MSZoning  GarageCond    YrSold  GarageQual  ExterCond  GarageCars  \
# Id
# 1461  136500.0    170000.0  155000.0    170000.0   167370.0    180150.0
# 1462  174000.0    170000.0  155000.0    170000.0   167370.0    180150.0
# 1463  174000.0    170000.0  155000.0    170000.0   167370.0    180150.0
# 1464  174000.0    170000.0  155000.0    170000.0   167370.0    180150.0
# 1465  174000.0    170000.0  155000.0    170000.0   167370.0    180150.0
# ...        ...         ...       ...         ...        ...         ...
# 2915  120500.0    132900.8  163995.0    143623.0   167370.0    180150.0
# 2916  120500.0    170000.0  163995.0    170000.0   167370.0    180150.0
# 2917  174000.0    170000.0  163995.0    170000.0   167370.0    180150.0
# 2918  174000.0    132900.8  163995.0    143623.0   167370.0    180150.0
# 2919  174000.0    170000.0  163995.0    170000.0   167370.0    180150.0
#
#       LotConfig  HeatingQC  Fireplaces  LandContour  KitchenQual  MasVnrType  \
# Id
# 1461   159697.5   135000.0    135000.0     162900.0     137000.0    143000.0
# 1462   160000.0   135000.0    135000.0     162900.0     201400.0    181000.0
# 1463   159697.5   152000.0    189975.0     162900.0     137000.0    143000.0
# 1464   159697.5   194700.0    189975.0     162900.0     201400.0    181000.0
# 1465   159697.5   194700.0    135000.0     222250.0     201400.0    143000.0
# ...         ...        ...         ...          ...          ...         ...
# 2915   159697.5   152000.0    135000.0     162900.0     137000.0    143000.0
# 2916   159697.5   135000.0    135000.0     162900.0     137000.0    143000.0
# 2917   159697.5   194700.0    189975.0     162900.0     137000.0    143000.0
# 2918   159697.5   135000.0    135000.0     162900.0     137000.0    143000.0
# 2919   159697.5   194700.0    189975.0     162900.0     137000.0    181000.0
#
#       FullBath  BsmtFullBath  KitchenAbvGr  LotShape  BsmtExposure  BsmtCond  \
# Id
# 1461  132375.0      174987.5      165550.0  146000.0      154000.0  165000.0
# 1462  132375.0      174987.5      165550.0  189000.0      154000.0  165000.0
# 1463  196750.0      174987.5      165550.0  189000.0      154000.0  165000.0
# 1464  196750.0      174987.5      165550.0  189000.0      154000.0  165000.0
# 1465  196750.0      174987.5      165550.0  189000.0      154000.0  165000.0
# ...        ...           ...           ...       ...           ...       ...
# 2915  132375.0      174987.5      165550.0  146000.0      154000.0  165000.0
# 2916  132375.0      174987.5      165550.0  146000.0      154000.0  165000.0
# 2917  132375.0      174987.5      165550.0  146000.0      154000.0  165000.0
# 2918  132375.0      174987.5      165550.0  146000.0      185850.0  165000.0
# 2919  196750.0      174987.5      165550.0  146000.0      185850.0  165000.0
#
#       BsmtQual  ExterQual  HalfBath  GarageFinish  BsmtHalfBath  LandSlope  \
# Id
# 1461  135500.0   139450.0  143000.0      135000.0      161033.5   161875.0
# 1462  135500.0   139450.0  189000.0      135000.0      161033.5   161875.0
# 1463  192070.0   139450.0  189000.0      215000.0      161033.5   161875.0
# 1464  135500.0   139450.0  189000.0      215000.0      161033.5   161875.0
# 1465  192070.0   220000.0  143000.0      190000.0      161033.5   161875.0
# ...        ...        ...       ...           ...           ...        ...
# 2915  135500.0   139450.0  189000.0      180000.0      161033.5   161875.0
# 2916  135500.0   139450.0  189000.0      135000.0      161033.5   161875.0
# 2917  135500.0   139450.0  143000.0      135000.0      161033.5   161875.0
# 2918  192070.0   139450.0  143000.0      180000.0      161033.5   161875.0
# 2919  192070.0   139450.0  189000.0      215000.0      161033.5   186700.0
#
#       PavedDrive  Utilities    Street  CentralAir  FireplaceQu
# Id
# 1461    168500.0   163000.0  163000.0    168000.0     199640.0
# 1462    168500.0   163000.0  163000.0    168000.0     199640.0
# 1463    168500.0   163000.0  163000.0    168000.0     187500.0
# 1464    168500.0   163000.0  163000.0    168000.0     206950.0
# 1465    168500.0   163000.0  163000.0    168000.0     199640.0
# ...          ...        ...       ...         ...          ...
# 2915    168500.0   163000.0  163000.0    168000.0     199640.0
# 2916    168500.0   163000.0  163000.0    168000.0     199640.0
# 2917    168500.0   163000.0  163000.0    168000.0     187500.0
# 2918    168500.0   163000.0  163000.0    168000.0     199640.0
# 2919    168500.0   163000.0  163000.0    168000.0     187500.0
#
# [1459 rows x 56 columns]

# %%
df_combined_continuous_categorical = df_train_continuous.merge(df_train_categorical,left_index=True,right_index=True)
df_combined_continuous_categorical
# Out:
#       GrLivArea    LotArea  BsmtFinSF1  BsmtUnfSF   1stFlrSF  TotalBsmtSF  \
# Id
# 1461  115268.84  196675.80   154242.42  171455.79  146681.53    156183.29
# 1462  160166.61  219555.05   199091.77  173939.15  199304.02    210757.52
# 1463  191273.61  215775.00   182243.29  169027.21  150570.49    161799.43
# 1464  188681.36  182455.20   163579.54  172441.83  150327.43    161555.25
# 1465  155085.80  139438.75   146212.57  185096.01  193349.05    204775.11
# ...         ...        ...         ...        ...        ...          ...
# 2915  135592.08  112891.90   146988.42  176495.55  104146.03    115161.05
# 2916  135592.08  112528.60   145995.54  171894.03  104146.03    115161.05
# 2917  149279.16  269145.50   249241.38  166525.59  186543.37    197938.07
# 2918  122941.90  186460.15   148238.69  177025.09  155674.75    159845.99
# 2919  229742.60  179419.05   178521.22  170871.47  158834.53    170101.55
#
#       GarageArea   2ndFlrSF  BsmtFinSF2  WoodDeckSF  OpenPorchSF  \
# Id
# 1461   240601.06   71631.97   153438.11   193583.42    194337.81
# 1462   135277.60   71631.97   149161.31   228036.96    199019.61
# 1463   178112.50  170227.62   149161.31   203388.38    198759.51
# 1464   175088.86  166057.03   149161.31   223543.02    199019.61
# 1465   184159.78   71631.97   149161.31   174518.22    205001.91
# ...          ...        ...         ...         ...          ...
# 2915    56662.96  143349.07   149161.31   174518.22    194337.81
# 2916   128726.38  143349.07   149161.31   174518.22    197459.01
# 2917   201797.68   71631.97   149161.31   239067.54    194337.81
# 2918    56662.96   71631.97   149161.31   185412.62    198499.41
# 2919   220443.46  231097.29   149161.31   200392.42    200580.21
#
#       EnclosedPorch  LotFrontage  ScreenPorch  Neighborhood  Exterior2nd  \
# Id
# 1461      118584.92    191312.57    178158.44      140000.0     200070.5
# 1462      118584.92    192625.54    152419.64      140000.0     138000.0
# 1463      118584.92    183434.75    152419.64      181000.0     200070.5
# 1464      118584.92    188686.63    152419.64      181000.0     200070.5
# 1465      118584.92    142732.68    183306.20      278000.0     155000.0
# ...             ...          ...          ...           ...          ...
# 2915      118584.92    113847.34    152419.64       88000.0     238750.0
# 2916      118584.92    113847.34    152419.64       88000.0     238750.0
# 2917      118584.92    296350.17    152419.64      153500.0     200070.5
# 2918      118584.92    167679.11    152419.64      153500.0     138225.0
# 2919      118584.92    183434.75    152419.64      153500.0     155000.0
#
#       MSSubClass  Exterior1st  YearBuilt  YearRemodAdd    GarageYrBlt  \
# Id
# 1461    159250.0     200000.0   138225.0      132750.0  135000.000000
# 1462    159250.0     138943.5   139500.0      136000.0  139000.000000
# 1463    215200.0     200000.0   207600.0      195700.0  200000.000000
# 1464    215200.0     200000.0   211000.0      195700.0  199900.000000
# 1465    192000.0     149900.0   189000.0      170000.0  189000.000000
# ...          ...          ...        ...           ...            ...
# 2915    146000.0     236500.0   124750.0      129250.0  160158.757732
# 2916    146000.0     236500.0   124750.0      129250.0  146500.000000
# 2917    159250.0     200000.0   154300.0      168250.0  151500.000000
# 2918    140750.0     149900.0   189000.0      170000.0  160158.757732
# 2919    215200.0     149900.0   194500.0      207750.0  193750.000000
#
#         MoSold  TotRmsAbvGrd  OverallQual  OverallCond  Condition1  SaleType  \
# Id
# 1461  163000.0      130250.0     133000.0     142750.0    140000.0  158000.0
# 1462  163000.0      155000.0     160000.0     142750.0    166500.0  158000.0
# 1463  165250.0      155000.0     133000.0     185000.0    166500.0  158000.0
# 1464  163000.0      184100.0     160000.0     142750.0    166500.0  158000.0
# 1465  151650.0      130250.0     269750.0     185000.0    166500.0  158000.0
# ...        ...           ...          ...          ...         ...       ...
# 2915  163000.0      130250.0     108000.0     145000.0    166500.0  158000.0
# 2916  147000.0      155000.0     108000.0     185000.0    166500.0  158000.0
# 2917  185900.0      184100.0     133000.0     145000.0    166500.0  158000.0
# 2918  165195.0      155000.0     133000.0     185000.0    166500.0  158000.0
# 2919  173000.0      252000.0     200141.0     185000.0    166500.0  158000.0
#
#       RoofMatl  BedroomAbvGr  Condition2  HouseStyle  Functional  GarageType  \
# Id
# 1461  162000.0      137250.0    163500.0    154750.0    165500.0    185000.0
# 1462  162000.0      169945.0    163500.0    154750.0    165500.0    185000.0
# 1463  162000.0      169945.0    163500.0    190000.0    165500.0    185000.0
# 1464  162000.0      169945.0    163500.0    190000.0    165500.0    185000.0
# 1465  162000.0      137250.0    163500.0    154750.0    165500.0    185000.0
# ...        ...           ...         ...         ...         ...         ...
# 2915  162000.0      169945.0    163500.0    190000.0    165500.0    159500.0
# 2916  162000.0      169945.0    163500.0    190000.0    165500.0    108000.0
# 2917  162000.0      193500.0    163500.0    154750.0    165500.0    129500.0
# 2918  162000.0      169945.0    163500.0    135960.0    165500.0    159500.0
# 2919  162000.0      169945.0    163500.0    190000.0    165500.0    185000.0
#
#       SaleCondition  RoofStyle  Electrical   Heating  BsmtFinType2  \
# Id
# 1461       160000.0   160000.0    170000.0  164500.0      154000.0
# 1462       160000.0   176500.0    170000.0  164500.0      167000.0
# 1463       160000.0   160000.0    170000.0  164500.0      167000.0
# 1464       160000.0   160000.0    170000.0  164500.0      167000.0
# 1465       160000.0   160000.0    170000.0  164500.0      167000.0
# ...             ...        ...         ...       ...           ...
# 2915       160000.0   160000.0    170000.0  164500.0      167000.0
# 2916       130000.0   160000.0    170000.0  164500.0      167000.0
# 2917       130000.0   160000.0    170000.0  164500.0      167000.0
# 2918       160000.0   160000.0    170000.0  164500.0      167000.0
# 2919       160000.0   160000.0    170000.0  164500.0      167000.0
#
#       BsmtFinType1  Foundation  BldgType  MSZoning  GarageCond    YrSold  \
# Id
# 1461      142000.0    141500.0  167900.0  136500.0    170000.0  155000.0
# 1462      149250.0    141500.0  167900.0  174000.0    170000.0  155000.0
# 1463      213750.0    205000.0  167900.0  174000.0    170000.0  155000.0
# 1464      213750.0    205000.0  167900.0  174000.0    170000.0  155000.0
# 1465      149250.0    205000.0  172200.0  174000.0    170000.0  155000.0
# ...            ...         ...       ...       ...         ...       ...
# 2915      161750.0    141500.0  137500.0  120500.0    132900.8  163995.0
# 2916      142000.0    141500.0  172200.0  120500.0    170000.0  163995.0
# 2917      149250.0    141500.0  167900.0  174000.0    170000.0  163995.0
# 2918      213750.0    205000.0  167900.0  174000.0    132900.8  163995.0
# 2919      139000.0    205000.0  167900.0  174000.0    170000.0  163995.0
#
#       GarageQual  ExterCond  GarageCars  LotConfig  HeatingQC  Fireplaces  \
# Id
# 1461    170000.0   167370.0    180150.0   159697.5   135000.0    135000.0
# 1462    170000.0   167370.0    180150.0   160000.0   135000.0    135000.0
# 1463    170000.0   167370.0    180150.0   159697.5   152000.0    189975.0
# 1464    170000.0   167370.0    180150.0   159697.5   194700.0    189975.0
# 1465    170000.0   167370.0    180150.0   159697.5   194700.0    135000.0
# ...          ...        ...         ...        ...        ...         ...
# 2915    143623.0   167370.0    180150.0   159697.5   152000.0    135000.0
# 2916    170000.0   167370.0    180150.0   159697.5   135000.0    135000.0
# 2917    170000.0   167370.0    180150.0   159697.5   194700.0    189975.0
# 2918    143623.0   167370.0    180150.0   159697.5   135000.0    135000.0
# 2919    170000.0   167370.0    180150.0   159697.5   194700.0    189975.0
#
#       LandContour  KitchenQual  MasVnrType  FullBath  BsmtFullBath  \
# Id
# 1461     162900.0     137000.0    143000.0  132375.0      174987.5
# 1462     162900.0     201400.0    181000.0  132375.0      174987.5
# 1463     162900.0     137000.0    143000.0  196750.0      174987.5
# 1464     162900.0     201400.0    181000.0  196750.0      174987.5
# 1465     222250.0     201400.0    143000.0  196750.0      174987.5
# ...           ...          ...         ...       ...           ...
# 2915     162900.0     137000.0    143000.0  132375.0      174987.5
# 2916     162900.0     137000.0    143000.0  132375.0      174987.5
# 2917     162900.0     137000.0    143000.0  132375.0      174987.5
# 2918     162900.0     137000.0    143000.0  132375.0      174987.5
# 2919     162900.0     137000.0    181000.0  196750.0      174987.5
#
#       KitchenAbvGr  LotShape  BsmtExposure  BsmtCond  BsmtQual  ExterQual  \
# Id
# 1461      165550.0  146000.0      154000.0  165000.0  135500.0   139450.0
# 1462      165550.0  189000.0      154000.0  165000.0  135500.0   139450.0
# 1463      165550.0  189000.0      154000.0  165000.0  192070.0   139450.0
# 1464      165550.0  189000.0      154000.0  165000.0  135500.0   139450.0
# 1465      165550.0  189000.0      154000.0  165000.0  192070.0   220000.0
# ...            ...       ...           ...       ...       ...        ...
# 2915      165550.0  146000.0      154000.0  165000.0  135500.0   139450.0
# 2916      165550.0  146000.0      154000.0  165000.0  135500.0   139450.0
# 2917      165550.0  146000.0      154000.0  165000.0  135500.0   139450.0
# 2918      165550.0  146000.0      185850.0  165000.0  192070.0   139450.0
# 2919      165550.0  146000.0      185850.0  165000.0  192070.0   139450.0
#
#       HalfBath  GarageFinish  BsmtHalfBath  LandSlope  PavedDrive  Utilities  \
# Id
# 1461  143000.0      135000.0      161033.5   161875.0    168500.0   163000.0
# 1462  189000.0      135000.0      161033.5   161875.0    168500.0   163000.0
# 1463  189000.0      215000.0      161033.5   161875.0    168500.0   163000.0
# 1464  189000.0      215000.0      161033.5   161875.0    168500.0   163000.0
# 1465  143000.0      190000.0      161033.5   161875.0    168500.0   163000.0
# ...        ...           ...           ...        ...         ...        ...
# 2915  189000.0      180000.0      161033.5   161875.0    168500.0   163000.0
# 2916  189000.0      135000.0      161033.5   161875.0    168500.0   163000.0
# 2917  143000.0      135000.0      161033.5   161875.0    168500.0   163000.0
# 2918  143000.0      180000.0      161033.5   161875.0    168500.0   163000.0
# 2919  189000.0      215000.0      161033.5   186700.0    168500.0   163000.0
#
#         Street  CentralAir  FireplaceQu
# Id
# 1461  163000.0    168000.0     199640.0
# 1462  163000.0    168000.0     199640.0
# 1463  163000.0    168000.0     187500.0
# 1464  163000.0    168000.0     206950.0
# 1465  163000.0    168000.0     199640.0
# ...        ...         ...          ...
# 2915  163000.0    168000.0     199640.0
# 2916  163000.0    168000.0     199640.0
# 2917  163000.0    168000.0     187500.0
# 2918  163000.0    168000.0     199640.0
# 2919  163000.0    168000.0     187500.0
#
# [1459 rows x 70 columns]

# %%
df_combined_continuous_categorical.isna().sum()
# Out:
# GrLivArea        0
# LotArea          0
# BsmtFinSF1       0
# BsmtUnfSF        0
# 1stFlrSF         0
# TotalBsmtSF      0
# GarageArea       0
# 2ndFlrSF         0
# BsmtFinSF2       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# LotFrontage      0
# ScreenPorch      0
# Neighborhood     0
# Exterior2nd      0
# MSSubClass       0
# Exterior1st      0
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt      0
# MoSold           0
# TotRmsAbvGrd     0
# OverallQual      0
# OverallCond      0
# Condition1       0
# SaleType         0
# RoofMatl         0
# BedroomAbvGr     0
# Condition2       0
# HouseStyle       0
# Functional       0
# GarageType       0
# SaleCondition    0
# RoofStyle        0
# Electrical       0
# Heating          0
# BsmtFinType2     0
# BsmtFinType1     0
# Foundation       0
# BldgType         0
# MSZoning         0
# GarageCond       0
# YrSold           0
# GarageQual       0
# ExterCond        0
# GarageCars       0
# LotConfig        0
# HeatingQC        0
# Fireplaces       0
# LandContour      0
# KitchenQual      0
# MasVnrType       0
# FullBath         0
# BsmtFullBath     0
# KitchenAbvGr     0
# LotShape         0
# BsmtExposure     0
# BsmtCond         0
# BsmtQual         0
# ExterQual        0
# HalfBath         0
# GarageFinish     0
# BsmtHalfBath     0
# LandSlope        0
# PavedDrive       0
# Utilities        0
# Street           0
# CentralAir       0
# FireplaceQu      0
# dtype: int64

# %%
df_combined_continuous_categorical.apply(axis='index',func=lambda x:(x==0).sum())
# Out:
# GrLivArea        0
# LotArea          0
# BsmtFinSF1       0
# BsmtUnfSF        0
# 1stFlrSF         0
# TotalBsmtSF      0
# GarageArea       0
# 2ndFlrSF         0
# BsmtFinSF2       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# LotFrontage      0
# ScreenPorch      0
# Neighborhood     0
# Exterior2nd      0
# MSSubClass       0
# Exterior1st      0
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt      0
# MoSold           0
# TotRmsAbvGrd     0
# OverallQual      0
# OverallCond      0
# Condition1       0
# SaleType         0
# RoofMatl         0
# BedroomAbvGr     0
# Condition2       0
# HouseStyle       0
# Functional       0
# GarageType       0
# SaleCondition    0
# RoofStyle        0
# Electrical       0
# Heating          0
# BsmtFinType2     0
# BsmtFinType1     0
# Foundation       0
# BldgType         0
# MSZoning         0
# GarageCond       0
# YrSold           0
# GarageQual       0
# ExterCond        0
# GarageCars       0
# LotConfig        0
# HeatingQC        0
# Fireplaces       0
# LandContour      0
# KitchenQual      0
# MasVnrType       0
# FullBath         0
# BsmtFullBath     0
# KitchenAbvGr     0
# LotShape         0
# BsmtExposure     0
# BsmtCond         0
# BsmtQual         0
# ExterQual        0
# HalfBath         0
# GarageFinish     0
# BsmtHalfBath     0
# LandSlope        0
# PavedDrive       0
# Utilities        0
# Street           0
# CentralAir       0
# FireplaceQu      0
# dtype: int64

# %%
from pickle import loads
with open('./model.sav','rb') as f:
    lr = loads(f.read())

# %%
lr
# Out:
# LinearRegression(fit_intercept=False)

# %%
predected_saleprice = lr.predict(df_combined_continuous_categorical.to_numpy())
predected_saleprice
# Out:
# array([[119335.13446245],
#        [182900.74605861],
#        [184322.73195588],
#        ...,
#        [185794.78303918],
#        [136377.90877641],
#        [221381.76604854]])

# %%
submission_df = pd.DataFrame({
                            'Id':df_combined_continuous_categorical.index,
                            'SalePrice':predected_saleprice.flatten()
                            })
submission_df
# Out:
#         Id      SalePrice
# 0     1461  119335.134462
# 1     1462  182900.746059
# 2     1463  184322.731956
# 3     1464  191538.470518
# 4     1465  213028.319645
# ...    ...            ...
# 1454  2915   84477.122823
# 1455  2916   89708.242474
# 1456  2917  185794.783039
# 1457  2918  136377.908776
# 1458  2919  221381.766049
#
# [1459 rows x 2 columns]

# %%
submission_df.isna().sum()
# Out:
# Id           0
# SalePrice    0
# dtype: int64

# %%
submission_df.to_csv('./submissions/submission.csv',index=False)
